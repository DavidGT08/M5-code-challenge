# %%
import pandas as pd
import numpy as np

# %%
def cargar_archivos():
    ruta = r"C:\Users\david\Documents\M5 challenge"

    df_sales_validation = pd.read_csv(ruta +"\sales_train_validation.csv")
    df_calendar = pd.read_csv(ruta+ "\calendar.csv")
    df_sell = pd.read_csv(ruta+"\sell_prices.csv")
    
    
    return df_sales_validation, df_calendar, df_sell

# %%
def formato_sales(df_sales_validation):
    # Convertir columnas de identidad a tipo 'category' y columnas de dias a tipo 'int16'

    columnas_identidad = ["id", "item_id", "dept_id", "cat_id", "store_id", "state_id"]
    columnas_dias = [col for col in df_sales_validation.columns if col.startswith("d_")]

    for col in columnas_identidad:
        df_sales_validation[col] = df_sales_validation[col].astype("category")

    df_sales_validation[columnas_dias] = df_sales_validation[columnas_dias].astype(np.int16)

    return df_sales_validation

# %%
formato_sales(df_sales_validation)
# Out:
#                                   id        item_id    dept_id   cat_id  \
# 0      HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 1      HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES
# 2      HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES
# 3      HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES
# 4      HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES
# ...                              ...            ...        ...      ...
# 30485    FOODS_3_823_WI_3_validation    FOODS_3_823    FOODS_3    FOODS
# 30486    FOODS_3_824_WI_3_validation    FOODS_3_824    FOODS_3    FOODS
# 30487    FOODS_3_825_WI_3_validation    FOODS_3_825    FOODS_3    FOODS
# 30488    FOODS_3_826_WI_3_validation    FOODS_3_826    FOODS_3    FOODS
# 30489    FOODS_3_827_WI_3_validation    FOODS_3_827    FOODS_3    FOODS
#
#       store_id state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  d_1906  \
# 0         CA_1       CA    0    0    0    0  ...       1       3       0
# 1         CA_1       CA    0    0    0    0  ...       0       0       0
# 2         CA_1       CA    0    0    0    0  ...       2       1       2
# 3         CA_1       CA    0    0    0    0  ...       1       0       5
# 4         CA_1       CA    0    0    0    0  ...       2       1       1
# ...        ...      ...  ...  ...  ...  ...  ...     ...     ...     ...
# 30485     WI_3       WI    0    0    2    2  ...       2       0       0
# 30486     WI_3       WI    0    0    0    0  ...       0       0       0
# 30487     WI_3       WI    0    6    0    2  ...       2       1       0
# 30488     WI_3       WI    0    0    0    0  ...       0       0       1
# 30489     WI_3       WI    0    0    0    0  ...       0       0       0
#
#        d_1907  d_1908  d_1909  d_1910  d_1911  d_1912  d_1913
# 0           1       1       1       3       0       1       1
# 1           0       0       1       0       0       0       0
# 2           1       1       1       0       1       1       1
# 3           4       1       0       1       3       7       2
# 4           0       1       1       2       2       2       4
# ...       ...     ...     ...     ...     ...     ...     ...
# 30485       0       0       0       1       0       0       1
# 30486       0       0       0       0       0       1       0
# 30487       2       0       1       0       0       1       0
# 30488       0       0       1       0       3       1       3
# 30489       0       0       0       0       0       0       0
#
# [30490 rows x 1919 columns]

# %%
df_sales_validation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30490 entries, 0 to 30489
# Columns: 1919 entries, id to d_1913
# dtypes: category(6), int16(1913)
# memory usage: 112.8 MB

# %%
def formato_calendar(df_calendar):
    # Convertir date a tipo 'datetime', rellenar Nans con 'No event' y convertir a tipo 'category', eliminar columnas innecesarias

    df_calendar["date"] = pd.to_datetime(df_calendar["date"], format="%Y-%m-%d",errors="coerce")

    columnas_eventos = ["event_name_1", "event_type_1", "event_name_2", "event_type_2"]
    for col in columnas_eventos:
        df_calendar[col] = df_calendar[col].fillna("No event").astype("category")

    columnnas_string = ["weekday", "d"]
    for col in columnnas_string:
        df_calendar[col] = df_calendar[col].astype("category")

    df_calendar = df_calendar.drop(columns=["wm_yr_wk", "wday", "month", "year"])


    return df_calendar

# %%
formato_calendar(df_calendar)
# Out:
#            date    weekday       d  event_name_1 event_type_1  event_name_2  \
# 0    2011-01-29   Saturday     d_1      No event     No event      No event
# 1    2011-01-30     Sunday     d_2      No event     No event      No event
# 2    2011-01-31     Monday     d_3      No event     No event      No event
# 3    2011-02-01    Tuesday     d_4      No event     No event      No event
# 4    2011-02-02  Wednesday     d_5      No event     No event      No event
# ...         ...        ...     ...           ...          ...           ...
# 1964 2016-06-15  Wednesday  d_1965      No event     No event      No event
# 1965 2016-06-16   Thursday  d_1966      No event     No event      No event
# 1966 2016-06-17     Friday  d_1967      No event     No event      No event
# 1967 2016-06-18   Saturday  d_1968      No event     No event      No event
# 1968 2016-06-19     Sunday  d_1969  NBAFinalsEnd     Sporting  Father's day
#
#      event_type_2  snap_CA  snap_TX  snap_WI
# 0        No event        0        0        0
# 1        No event        0        0        0
# 2        No event        0        0        0
# 3        No event        1        1        0
# 4        No event        1        0        1
# ...           ...      ...      ...      ...
# 1964     No event        0        1        1
# 1965     No event        0        0        0
# 1966     No event        0        0        0
# 1967     No event        0        0        0
# 1968     Cultural        0        0        0
#
# [1969 rows x 10 columns]

# %%
df_calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1969 entries, 0 to 1968
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1969 non-null   datetime64[ns]
#  1   wm_yr_wk      1969 non-null   int64
#  2   weekday       1969 non-null   category
#  3   wday          1969 non-null   int64
#  4   month         1969 non-null   int64
#  5   year          1969 non-null   int64
#  6   d             1969 non-null   category
#  7   event_name_1  1969 non-null   category
#  8   event_type_1  1969 non-null   category
#  9   event_name_2  1969 non-null   category
#  10  event_type_2  1969 non-null   category
#  11  snap_CA       1969 non-null   int64
#  12  snap_TX       1969 non-null   int64
#  13  snap_WI       1969 non-null   int64
# dtypes: category(6), datetime64[ns](1), int64(7)
# memory usage: 218.8 KB
